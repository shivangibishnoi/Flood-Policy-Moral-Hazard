# %%
import altair as alt
import pandas as pd

# %%
# import dataset
df = pd.read_csv("world-data.csv")
df
# Out:
#       Category  Year     Value
# 0          NaN  1986  2.003000
# 1          NaN  1987  2.063048
# 2          NaN  1988  2.101494
# 3          NaN  1989  2.120321
# 4          NaN  1990  2.120751
# ..         ...   ...       ...
# 145  Very High  2011  2.398795
# 146  Very High  2012  2.398839
# 147  Very High  2013  2.460401
# 148  Very High  2014  2.577580
# 149  Very High  2015  2.744430
#
# [150 rows x 3 columns]

# %%
# create multiple line chart
line = alt.Chart(df).mark_line().encode(
    x='Year:O',
    y='Value:Q',
    color='Category:N'
).properties(
    width=600,
    height=400
)

# %%
# view the chart
line
# Out:
# alt.Chart(...)
